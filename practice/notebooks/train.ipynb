# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics opencv-python cython cython_bbox loguru lap lapjv
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 91.7 MB/s eta 0:00:00
# ...
#   Created wheel for cython_bbox: filename=cython_bbox-0.1.5-cp312-cp312-linux_x86_64.whl size=111559 sha256=fd10063af3ec916ea08016d460b9709d99d0bbc7a9b8b03856925ad278d508d6
#   Stored in directory: /root/.cache/pip/wheels/f1/e7/0a/7c310ac8921f2c1e61e58f80585f1ce0be9e4a36d280771857
# ...
#   Created wheel for lapjv: filename=lapjv-1.3.27-cp312-cp312-linux_x86_64.whl size=142100 sha256=491d6ce116e802c1e5f6c700adde48d7fd846e1b1413c7293607d6459aeadc08
#   Stored in directory: /root/.cache/pip/wheels/8a/b5/65/3cbb79ec56625bf795b818545064022bc30460016a31ab9b5f
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolo11x.pt')

result = model.train(data='/content/drive/MyDrive/data/WildFire_Smoke_Dataset_YOLO/data.yaml', epochs=100, imgsz=640, batch=8)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
